# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food = df_food[['calories_day', 'weight', 'Gender']]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_cleaned = df_food.dropna()
df_food_cleaned
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
# Create a copy of the dataframe to avoid SettingWithCopyWarning
df_food_cleaned = df_food[['calories_day', 'weight', 'Gender']].copy()

# Convert the columns to numeric and handle errors by coercing invalid values to NaN
df_food_cleaned['calories_day'] = pd.to_numeric(df_food_cleaned['calories_day'], errors='coerce')
df_food_cleaned['weight'] = pd.to_numeric(df_food_cleaned['weight'], errors='coerce')

# Drop rows where conversion resulted in NaNs
df_food_cleaned = df_food_cleaned.dropna()

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_cleaned.to_csv('cleaned_food_data.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
salary_data_set_path = 'data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'

df_salary = pd.read_csv(salary_data_set_path, sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 
                     'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 
                     'field_yoe', 'highest_education', 'gender', 'race']

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: industry, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_tech_usd = df_salary_tech[df_salary_tech['currency'] == 'USD']
df_salary_tech_usd
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech_usd['country'].value_counts()
# Out:
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Pakistan                       1
# Puerto Rico                    1
# America                        1
# Uniyed states                  1
# Burma                          1
# Name: country, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
df_salary_tech_usd = df_salary_tech_usd.copy()  # Create a deep copy to avoid the warning
df_salary_tech_usd['country'] = df_salary_tech_usd['country'].replace(['United States', 'United States of America', 'USA', 'US'], 'US')

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech_usd['country'].value_counts()
# Out:
# US                3300
# U.S.               108
# United States       68
# Usa                 59
# USA                 56
#                   ...
# Pakistan             1
# Puerto Rico          1
# America              1
# Uniyed states        1
# Burma                1
# Name: country, Length: 73, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

df_salary_tech_usd['country'] = df_salary_tech_usd['country'].str.lower().replace(
    to_replace=r'\bunited\s*(states|states\s*of\s*america)\b|\bu\.s\.a\b|\bu\.s\b|\bunites\s*states\b|\bunited\s*stateds\b|\bunited\s*stares\b|\buniyed\s*states\b|\bus\.\b|\bus of america\b|\b us\b',
    value='us',
    regex=True
)


df_salary_tech_usd['country'] = df_salary_tech_usd['country'].replace({
    'australian': 'australia',
    'danmark': 'denmark',
    'san francisco': 'us',  # If this represents a city, otherwise review
    'ss': 'us'
})


df_salary_tech_usd['country'].value_counts()
# Out:
# us                      3589
# us                       135
# israel                     5
# canada                     4
# denmark                    3
# singapore                  2
# france                     2
# poland                     2
# new zealand                2
# brazil                     2
# spain                      2
# united kingdom             2
# australia                  2
# us.                        2
# india                      2
# remote (philippines)       1
# romania                    1
# nigeria                    1
# nigeria                    1
# ghana                      1
# colombia                   1
# thailand                   1
# jamaica                    1
# australian                 1
# japan                      1
# netherlands                1
# china                      1
# puerto rico                1
# pakistan                   1
# canada                     1
# cuba                       1
# mexico                     1
# ...

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

country_counts = df_salary_tech_usd['country'].value_counts()

country_counts
# Out:
# us                      3589
# us                       135
# israel                     5
# canada                     4
# denmark                    3
# singapore                  2
# france                     2
# poland                     2
# new zealand                2
# brazil                     2
# spain                      2
# united kingdom             2
# australia                  2
# us.                        2
# india                      2
# remote (philippines)       1
# romania                    1
# nigeria                    1
# nigeria                    1
# ghana                      1
# colombia                   1
# thailand                   1
# jamaica                    1
# australian                 1
# japan                      1
# netherlands                1
# china                      1
# puerto rico                1
# pakistan                   1
# canada                     1
# cuba                       1
# mexico                     1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary_tech_usd['salary'] = df_salary_tech_usd['salary'].str.replace(',', '').astype(float)


state_salary_stats = df_salary_tech_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values(by='mean', ascending=False)


state_salary_stats
# Out:
#                                   min           mean        max
# state
# Michigan, Texas, Washington  340000.0  340000.000000   340000.0
# California, Oregon           200000.0  200000.000000   200000.0
# California, Colorado         176000.0  176000.000000   176000.0
# Georgia, Massachusetts       175000.0  175000.000000   175000.0
# Florida                       28800.0  157457.232143  2600000.0
# ...                               ...            ...        ...
# Louisiana                     35360.0   83269.090909   150000.0
# Massachusetts, Pennsylvania   83000.0   83000.000000    83000.0
# California, Maryland          81500.0   81500.000000    81500.0
# Arkansas                          4.0   74257.000000   144000.0
# Alabama, Montana              72000.0   72000.000000    72000.0
#
# [66 rows x 3 columns]

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
fixed

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

fixed

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech_usd['timestamp'] = pd.to_datetime(df_salary_tech_usd['timestamp'], errors='coerce')


df_salary_filtered = df_salary_tech_usd[df_salary_tech_usd['timestamp'].dt.year.isin([2021, 2022, 2023])]


state_salary_stats_filtered = df_salary_filtered.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values(by='mean', ascending=False)


state_salary_stats_filtered
# Out:
#                                     min           mean       max
# state
# Michigan, Texas, Washington    340000.0  340000.000000  340000.0
# California, Oregon             200000.0  200000.000000  200000.0
# California, Colorado           176000.0  176000.000000  176000.0
# Georgia, Massachusetts         175000.0  175000.000000  175000.0
# Alabama, District of Columbia  156000.0  156000.000000  156000.0
# ...                                 ...            ...       ...
# Louisiana                       35360.0   83269.090909  150000.0
# Massachusetts, Pennsylvania     83000.0   83000.000000   83000.0
# Arkansas                        55000.0   81682.300000  144000.0
# California, Maryland            81500.0   81500.000000   81500.0
# Alabama, Montana                72000.0   72000.000000   72000.0
#
# [66 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary['salary'] = df_salary['salary'].str.replace(',', '').astype(float)


df_salary['timestamp'] = pd.to_datetime(df_salary['timestamp'], errors='coerce')


state_salary_stats_all = df_salary.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values(by='mean', ascending=False)


state_salary_stats_all
# Out:
#                                                           min          mean  \
# state
# Alabama, South Carolina                             5000000.0  5.000000e+06
# Michigan, Texas, Washington                          340000.0  3.400000e+05
# Indiana, Ohio                                        245000.0  2.450000e+05
# Alaska                                                27040.0  2.286546e+05
# Colorado, Nevada                                     190000.0  1.900000e+05
# ...                                                       ...           ...
# Alabama, California                                   29120.0  2.912000e+04
# District of Columbia, Maryland, Pennsylvania, V...    27040.0  2.704000e+04
# Maryland, New York                                    14000.0  1.400000e+04
# Alabama, Alaska, Arizona                                 15.0  1.500000e+01
# Colorado, Delaware, New Jersey, West Virginia, ...        5.0  5.000000e+00
#
# ...

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
def format_currency(value):
    return "${:,.2f}".format(value)


formatted_state_salary_stats = state_salary_stats_all.applymap(format_currency)

formatted_state_salary_stats
# Out:
#                                                               min  \
# state
# Alabama, South Carolina                             $5,000,000.00
# Michigan, Texas, Washington                           $340,000.00
# Indiana, Ohio                                         $245,000.00
# Alaska                                                 $27,040.00
# Colorado, Nevada                                      $190,000.00
# ...                                                           ...
# Alabama, California                                    $29,120.00
# District of Columbia, Maryland, Pennsylvania, V...     $27,040.00
# Maryland, New York                                     $14,000.00
# Alabama, Alaska, Arizona                                   $15.00
# Colorado, Delaware, New Jersey, West Virginia, ...          $5.00
#
#                                                              mean  \
# state
# Alabama, South Carolina                             $5,000,000.00
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
df_salary['state'] = df_salary['state'].astype(str)


df_salary_single_state = df_salary[~df_salary['state'].str.contains(',')]


state_salary_stats_single = df_salary_single_state.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values(by='mean', ascending=False)


state_salary_stats_single
# Out:
#                           min          mean           max
# state
# nan                       0.0  1.593727e+06  6.000070e+09
# Alaska                27040.0  2.286546e+05  1.000000e+07
# California                0.0  1.143921e+05  8.750000e+05
# Washington               72.0  1.078039e+05  1.260000e+06
# District of Columbia     40.0  1.064984e+05  1.334782e+06
# New York                 80.0  1.052878e+05  3.000000e+06
# New Jersey            14850.0  1.010739e+05  5.000044e+06
# Massachusetts           155.0  9.872034e+04  1.650000e+06
# Alabama                   0.0  9.817848e+04  3.600000e+06
# Virginia                 57.0  9.467939e+04  1.300000e+06
# Connecticut               0.0  9.367637e+04  1.900000e+06
# Illinois                  0.0  9.034076e+04  1.100000e+06
# Colorado                 65.0  8.949091e+04  6.300000e+05
# Maryland                  0.0  8.947052e+04  3.532000e+05
# Oregon                    0.0  8.890491e+04  3.200000e+05
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
quantiles = [0, 0.05, 0.25, 0.5, 0.75, 0.95, 1]


state_salary_quantiles = df_salary_single_state.groupby('state')['salary'].quantile(quantiles).unstack()


state_salary_quantiles['count'] = df_salary_single_state.groupby('state')['salary'].count()


state_salary_quantiles_sorted = state_salary_quantiles.sort_values(by=0.5, ascending=False)


state_salary_quantiles_sorted
# Out:
#                           0.0      0.05     0.25       0.5      0.75  \
# state
# California                0.0  42000.00  72000.0  100280.0  147000.0
# Washington               72.0  40000.00  65000.0   91000.0  135000.0
# New York                 80.0  40752.00  64575.0   90000.0  127000.0
# District of Columbia     40.0  48050.00  66700.0   90000.0  125000.0
# Massachusetts           155.0  42000.00  64000.0   86000.0  120000.0
# Maryland                  0.0  40150.00  60000.0   82000.0  110000.0
# Connecticut               0.0  33872.50  62000.0   82000.0  100000.0
# Virginia                 57.0  37410.00  58812.5   81000.0  114850.0
# Delaware              35000.0  40480.00  57546.5   80145.0  105500.0
# Oregon                    0.0  36550.00  58050.0   78000.0  109576.5
# Illinois                  0.0  37440.00  56000.0   76000.0  110000.0
# Colorado                 65.0  38264.00  58000.0   75550.0  110250.0
# ...
