# %%
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn
import sklearn.datasets
from sklearn.metrics import accuracy_score
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# # The Iris Dataset
#
# Here are some pictures of the iris subspecies that we will be working with!
#
# ### Iris Setosa
# ![alt text](images/irissetosa2.jpg "setosa")
# ### Iris Versicolor
# ![alt text](images/versicolor.jpg "versicolor")
# ### Iris Virginica
# ![alt text](images/virginica.jpg "virginica")

# %% [markdown]
# ## About the Iris Dataset

# %%
#  in sklearn datasets, the data is stored in 'data'.  the columns are stored in 'feature_names'
iris = sklearn.datasets.load_iris()
iris_df=pd.DataFrame(iris.data, columns=iris['feature_names'])
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#  We will add labels for later to see how well our labeling goes
iris_labeled_df = iris_df.copy(deep=True)
iris_labeled_df['species_index'] = iris['target']
#  'target'  contains the coded species label (0,1,2).  The lookup is in 'target names'.
iris_names = iris['target_names']
# we convert to a dict to add the labels to iris_labeled_df
iris_name_dict = dict(zip(range(4), iris_names ))
iris_labeled_df['species'] = iris_labeled_df['species_index'].map(iris_name_dict)

# %%
#  We can use pairplot to plot scatterplots of everything with everything else.  We put hisograms on the diagonal
cols = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)']
sns.pairplot(iris_labeled_df, vars=cols,  hue='species')

# %% [markdown]
# ## K-Means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0)

# %%
iris_df['labels'] = kmeans.fit_predict(iris_df)

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      labels
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 145       2
# 146       0
# 147       2
# 148       2
# 149       0
#
# [150 rows x 5 columns]

# %%
cols = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)']
sns.pairplot(iris_df, vars=cols,  hue='labels')

# %% [markdown]
# ### Accuracy and Confusion
#
# There are a number of accuracy metrics we can use when we have the "correct"  answer to compare to.  In this case, we can compare the species to see how often it gets the correct answer.  The *accuracy* is the ratio of correct assigments to the number of total assignments.  The "confusion matrix" is a $N\times N$ matrix that displays the number of predictions in eatch categorical value by the number of given values.
#
# As a check, the accuracy is the trace (sum of the diagonal values) divided by the total number of cases

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(iris_df.labels, iris_labeled_df['species_index'])
# Out:
# array([[ 0, 48, 14],
#        [50,  0,  0],
#        [ 0,  2, 36]], dtype=int64)

# %%
#  K-means doesn't know how to associate its labels with the orig ones.  We can fix that:
map_cluster_dict = dict(zip((0,1,2), (1,0,2) ))

# %%
# Better!
conf = confusion_matrix(iris_df.labels.map(map_cluster_dict), iris_labeled_df['species_index'])
conf
# Out:
# array([[50,  0,  0],
#        [ 0, 48, 14],
#        [ 0,  2, 36]], dtype=int64)

# %%
accuracy_score(iris_df.labels.map(map_cluster_dict), iris_labeled_df['species_index'])
# Out:
# 0.8933333333333333

# %%
# Note that this is the same as:
np.trace(conf)/np.sum(conf)
# Out:
# 0.8933333333333333

# %% [markdown]
# ## Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
# courtosy sklearn.org
import numpy as np
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import load_iris


X = iris.data

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.title('Hierarchical Clustering Dendrogram')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=3)
plt.xlabel('Number of points in node (or index of point if no parenthesis).')
plt.show()

# %%
newmodel = AgglomerativeClustering(n_clusters=3)
iris_df['heirarchical_labels'] = newmodel.fit_predict(X)

# %%
cols = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)']
sns.pairplot(iris_df, vars=cols, hue='heirarchical_labels')

# %%
confusion_matrix(iris_df.heirarchical_labels, iris_labeled_df['species_index'])
# Out:
# array([[ 0, 49, 15],
#        [50,  0,  0],
#        [ 0,  1, 35]], dtype=int64)

# %%
# again, we shuffle since our algorithm is "untrained"
# performance is similar
h_map_cluster_dict = dict(zip((1, 0, 2), (0, 1, 2) ))
confusion_matrix(iris_df.heirarchical_labels.map(h_map_cluster_dict), iris_labeled_df['species_index'])
# Out:
# array([[50,  0,  0],
#        [ 0, 49, 15],
#        [ 0,  1, 35]], dtype=int64)

# %%
accuracy_score(iris_df.heirarchical_labels.map(h_map_cluster_dict), iris_labeled_df['species_index'])
# Out:
# 0.8933333333333333

# %% [markdown]
# ## DBSCAN

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN

db = DBSCAN().fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 17

# %% [markdown]
# DBSCAN  doesn't do a great job, since the metrics of two of the species are spatially similar.  So, it finds 2 clusters rather than 3

# %% [markdown]
# # Market Analysis with APRIORI:  Coffee Shop Orders

# %%
# %pip install mlxtend
# %pip install networkx
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('data/Coffe Shop Sales.xlsx - MBA_Master.csv')

# Show the first 10 data points.
df.head(10)
# Out:
#    transaction_number  amount                 item
# 0                   6       1            Latte Hot
# 1                   6       1        Americano Hot
# 2                   6       1                  V60
# 3                   6       1             Brownies
# 4                   7       1                  V60
# 5                   7       1     Pain Au Chocolat
# 6                   8       1                  V60
# 7                   9       1  Pistachio Croissant
# 8                   9       1                  V60
# 9                   9       1          Carrot cake

# %%
df_pivot = df.pivot_table(index='transaction_number', columns='item', values='amount', aggfunc='sum').fillna(0)

# Show the size of the pivoted table.
print('Table size: %d rows \u00d7 %d columns' % df_pivot.shape)
df_pivot.head()
# Out:
# Table size: 3131 rows × 45 columns
# item                Almond Croisant  Americano Hot  Americano Iced  \
# transaction_number
# 6                               0.0            1.0             0.0
# 7                               0.0            0.0             0.0
# 8                               0.0            0.0             0.0
# 9                               0.0            0.0             0.0
# 441                             0.0            0.0             0.0
#
# item                Apple Turnover  Blueberry Muffins  Brownies  \
# transaction_number
# 6                              0.0                0.0       1.0
# 7                              0.0                0.0       0.0
# 8                              0.0                0.0       0.0
# 9                              0.0                0.0       0.0
# 441                            0.0                0.0       0.0
#
# item                Cake Of The Day  Cappucino Hot  Cappucino Iced  \
# transaction_number
# 6                               0.0            0.0             0.0
# 7                               0.0            0.0             0.0
# 8                               0.0            0.0             0.0
# 9                               0.0            0.0             0.0
# 441                             0.0            0.0             0.0
#
# item                Carrot cake  ...  Mochaccino Iced  Pain Au Chocolat  \
# transaction_number               ...
# 6                           0.0  ...              0.0               0.0
# 7                           0.0  ...              0.0               1.0
# 8                           0.0  ...              0.0               0.0
# 9                           1.0  ...              0.0               0.0
# 441                         0.0  ...              0.0               0.0
#
# item                Pain Au Suisse  PiccoloHot  PiccoloIced  \
# transaction_number
# 6                              0.0         0.0          0.0
# 7                              0.0         0.0          0.0
# 8                              0.0         0.0          0.0
# 9                              0.0         0.0          0.0
# 441                            0.0         0.0          0.0
#
# item                Pistachio Croissant  Plain Croisant  Tiramisu  \
# transaction_number
# 6                                   0.0             0.0       0.0
# 7                                   0.0             0.0       0.0
# 8                                   0.0             0.0       0.0
# 9                                   1.0             0.0       0.0
# 441                                 0.0             0.0       0.0
#
# item                Tiramisu cake  V60
# transaction_number
# 6                             0.0  1.0
# 7                             0.0  1.0
# 8                             0.0  1.0
# 9                             0.0  1.0
# 441                           0.0  0.0
#
# [5 rows x 45 columns]

# %%
# Show what the top transactions with the highest amounts look like transposed.
df_pivot[df_pivot.select_dtypes(np.number)
                 .apply(lambda x: 4 < x, axis=1)
                 .any(axis=1)] \
        .T \
        .style \
        .background_gradient(axis=None) \
        .format('{:,.0f}')
# Out:
# <style type="text/css">
# #T_c3a11_row0_col0, #T_c3a11_row0_col1, #T_c3a11_row0_col3, #T_c3a11_row0_col4, #T_c3a11_row0_col5, #T_c3a11_row0_col6, #T_c3a11_row0_col7, #T_c3a11_row0_col9, #T_c3a11_row0_col10, #T_c3a11_row1_col1, #T_c3a11_row1_col3, #T_c3a11_row1_col4, #T_c3a11_row1_col6, #T_c3a11_row1_col7, #T_c3a11_row1_col9, #T_c3a11_row2_col0, #T_c3a11_row2_col1, #T_c3a11_row2_col2, #T_c3a11_row2_col3, #T_c3a11_row2_col4, #T_c3a11_row2_col5, #T_c3a11_row2_col7, #T_c3a11_row2_col8, #T_c3a11_row2_col9, #T_c3a11_row2_col10, #T_c3a11_row3_col0, #T_c3a11_row3_col1, #T_c3a11_row3_col2, #T_c3a11_row3_col3, #T_c3a11_row3_col4, #T_c3a11_row3_col5, #T_c3a11_row3_col6, #T_c3a11_row3_col7, #T_c3a11_row3_col8, #T_c3a11_row3_col9, #T_c3a11_row3_col10, #T_c3a11_row4_col0, #T_c3a11_row4_col1, #T_c3a11_row4_col2, #T_c3a11_row4_col3, #T_c3a11_row4_col4, #T_c3a11_row4_col5, #T_c3a11_row4_col6, #T_c3a11_row4_col7, #T_c3a11_row4_col8, #T_c3a11_row4_col9, #T_c3a11_row4_col10, #T_c3a11_row5_col0, #T_c3a11_row5_col1, #T_c3a11_row5_col2, #T_c3a11_row5_col3, #T_c3a11_row5_col4, #T_c3a11_row5_col5, #T_c3a11_row5_col6, #T_c3a11_row5_col7, #T_c3a11_row5_col9, #T_c3a11_row5_col10, #T_c3a11_row6_col0, #T_c3a11_row6_col1, #T_c3a11_row6_col2, #T_c3a11_row6_col3, #T_c3a11_row6_col4, #T_c3a11_row6_col7, #T_c3a11_row6_col8, #T_c3a11_row6_col9, #T_c3a11_row6_col10, #T_c3a11_row7_col1, #T_c3a11_row7_col2, #T_c3a11_row7_col3, #T_c3a11_row7_col4, #T_c3a11_row7_col6, #T_c3a11_row7_col7, #T_c3a11_row7_col8, #T_c3a11_row7_col9, #T_c3a11_row8_col0, #T_c3a11_row8_col1, #T_c3a11_row8_col2, #T_c3a11_row8_col3, #T_c3a11_row8_col5, #T_c3a11_row8_col6, #T_c3a11_row8_col7, #T_c3a11_row8_col8, #T_c3a11_row8_col9, #T_c3a11_row8_col10, #T_c3a11_row9_col0, #T_c3a11_row9_col1, #T_c3a11_row9_col2, #T_c3a11_row9_col3, #T_c3a11_row9_col4, #T_c3a11_row9_col5, #T_c3a11_row9_col6, #T_c3a11_row9_col7, #T_c3a11_row9_col8, #T_c3a11_row9_col9, #T_c3a11_row10_col0, #T_c3a11_row10_col1, #T_c3a11_row10_col2, #T_c3a11_row10_col3, #T_c3a11_row10_col4, #T_c3a11_row10_col5, #T_c3a11_row10_col6, #T_c3a11_row10_col7, #T_c3a11_row10_col8, #T_c3a11_row10_col9, #T_c3a11_row10_col10, #T_c3a11_row11_col0, #T_c3a11_row11_col1, #T_c3a11_row11_col2, #T_c3a11_row11_col3, #T_c3a11_row11_col4, #T_c3a11_row11_col5, #T_c3a11_row11_col6, #T_c3a11_row11_col7, #T_c3a11_row11_col8, #T_c3a11_row11_col9, #T_c3a11_row11_col10, #T_c3a11_row12_col0, #T_c3a11_row12_col1, #T_c3a11_row12_col2, #T_c3a11_row12_col3, #T_c3a11_row12_col4, #T_c3a11_row12_col5, #T_c3a11_row12_col6, #T_c3a11_row12_col7, #T_c3a11_row12_col8, #T_c3a11_row12_col9, #T_c3a11_row12_col10, #T_c3a11_row13_col0, #T_c3a11_row13_col1, #T_c3a11_row13_col2, #T_c3a11_row13_col3, #T_c3a11_row13_col4, #T_c3a11_row13_col5, #T_c3a11_row13_col6, #T_c3a11_row13_col7, #T_c3a11_row13_col8, #T_c3a11_row13_col9, #T_c3a11_row13_col10, #T_c3a11_row14_col0, #T_c3a11_row14_col1, #T_c3a11_row14_col2, #T_c3a11_row14_col3, #T_c3a11_row14_col4, #T_c3a11_row14_col5, #T_c3a11_row14_col6, #T_c3a11_row14_col7, #T_c3a11_row14_col8, #T_c3a11_row14_col9, #T_c3a11_row14_col10, #T_c3a11_row15_col0, #T_c3a11_row15_col1, #T_c3a11_row15_col2, #T_c3a11_row15_col3, #T_c3a11_row15_col4, #T_c3a11_row15_col5, #T_c3a11_row15_col6, #T_c3a11_row15_col7, #T_c3a11_row15_col9, #T_c3a11_row15_col10, #T_c3a11_row16_col0, #T_c3a11_row16_col1, #T_c3a11_row16_col2, #T_c3a11_row16_col3, #T_c3a11_row16_col4, #T_c3a11_row16_col5, #T_c3a11_row16_col7, #T_c3a11_row16_col8, #T_c3a11_row16_col9, #T_c3a11_row16_col10, #T_c3a11_row17_col1, #T_c3a11_row17_col2, #T_c3a11_row17_col3, #T_c3a11_row17_col4, #T_c3a11_row17_col5, #T_c3a11_row17_col6, #T_c3a11_row17_col7, #T_c3a11_row17_col8, #T_c3a11_row17_col9, #T_c3a11_row17_col10, #T_c3a11_row18_col0, #T_c3a11_row18_col1, #T_c3a11_row18_col2, #T_c3a11_row18_col3, #T_c3a11_row18_col4, #T_c3a11_row18_col5, #T_c3a11_row18_col6, #T_c3a11_row18_col7, #T_c3a11_row18_col8, #T_c3a11_row18_col9, #T_c3a11_row18_col10, #T_c3a11_row19_col0, #T_c3a11_row19_col1, #T_c3a11_row19_col2, #T_c3a11_row19_col3, #T_c ...

# %%
df_pivot = df_pivot.map(lambda x: int(0 < x))

# Show what the first 10 look like transposed.
df_pivot.head(10) \
        .T \
        .style \
        .apply(lambda x: np.where(x, 'background: navy; color: white', ''), axis=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df_pivot = df_pivot.map(lambda x: int(0 < x))
#       3 # Show what the first 10 look like transposed.
#       4 df_pivot.head(10) \
#       5         .T \
#       6         .style \
#       7         .apply(lambda x: np.where(x, 'background: navy; color: white', ''), axis=None)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
# our minimum support
support = 0.01 
frequent_items = apriori(df_pivot, min_support=support, use_colnames=True)
frequent_items.sort_values('support', ascending=False)
# Out:
# C:\Users\ofirB\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 # our minimum support
#       2 support = 0.01
# ----> 3 frequent_items = apriori(df_pivot, min_support=support, use_colnames=True)
#       4 frequent_items.sort_values('support', ascending=False)
#
# File ~\anaconda3\lib\site-packages\mlxtend\frequent_patterns\apriori.py:241, in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     234 if min_support <= 0.0:
#     235     raise ValueError(
#     236         "`min_support` must be a positive "
#     237         "number within the interval `(0, 1]`. "
#     238         "Got %s." % min_support
#     239     )
# --> 241 fpc.valid_input_check(df)
#     243 if hasattr(df, "sparse"):
#     244     # DataFrame with SparseArray (pandas >= 0.24)
#     245     if df.size == 0:
#
# File ~\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:131, in valid_input_check(df)
#     126 val = values[tuple(loc[0] for loc in idxs)]
#     127 s = (
#     128     "The allowed values for a DataFrame"
#     129     " are True, False, 0, 1. Found value %s" % (val)
#     130 )
# --> 131 raise ValueError(s)
#
# ValueError: The allowed values for a DataFrame are True, False, 0, 1. Found value 3.0

# %% [markdown]
# "Lift" is the ratio of the target reponse given the antecedent relative to no condition. In conditional probability speak this is:
# $$
# L = \frac{P_{A|B}}{P_B}
# $$
# High lift suggests that the products tend to purchased together

# %%
metric = 'lift'
min_treshold = 1

rules = association_rules(frequent_items, metric=metric, min_threshold=min_treshold)[['antecedents','consequents','support','confidence','lift']]
rules.reset_index(drop=True).sort_values('confidence', ascending=False, inplace = True)

# Show the metrics.
rules.sort_values(['antecedents', 'consequents']) \
     .set_index(['antecedents', 'consequents']) \
     .style \
     .set_table_styles([{'selector': 'th.row_heading', 'props': [('vertical-align', 'text-top')]}]) \
     .background_gradient(axis=0) \
     .format_index(', '.join)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       1 metric = 'lift'
#       2 min_treshold = 1
# ----> 4 rules = association_rules(frequent_items, metric=metric, min_threshold=min_treshold)[['antecedents','consequents','support','confidence','lift']]
#       5 rules.reset_index(drop=True).sort_values('confidence', ascending=False, inplace = True)
#       7 # Show the metrics.
#
# NameError: name 'frequent_items' is not defined

# %%
# First we build a network from the association rule data
import networkx as nx

from_nodes = rules.antecedents.apply(', '.join)
to_nodes = rules.consequents.apply(', '.join)
cxns = zip(from_nodes, to_nodes)

G = nx.MultiDiGraph()
G.add_edges_from(cxns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       1 # First we build a network from the association rule data
#       2 import networkx as nx
# ----> 4 from_nodes = rules.antecedents.apply(', '.join)
#       5 to_nodes = rules.consequents.apply(', '.join)
#       6 cxns = zip(from_nodes, to_nodes)
#
# NameError: name 'rules' is not defined

# %%
plt.figure(1, figsize=(8, 8))
nx.draw_networkx(G, arrows=True, node_size=1000, font_size=10, node_color='tab:green', font_color='blue', connectionstyle='arc3, rad=0.1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 plt.figure(1, figsize=(8, 8))
# ----> 2 nx.draw_networkx(G, arrows=True, node_size=1000, font_size=10, node_color='tab:green', font_color='blue', connectionstyle='arc3, rad=0.1')
#
# NameError: name 'G' is not defined

# %% [markdown]
# Here, we see that the arrows flow both ways.  This shouldn't be suprising since the data contains purchases that happen at the same time.

# %%
rules_even = rules.iloc[::2, :].copy() # Keep only even rows.
rules_even.antecedents = rules_even.antecedents.apply(', '.join) # Get rid of frozensets.
rules_even.consequents = rules_even.consequents.apply(', '.join) # Get rid of frozensets.
rules_even['cxns'] = rules_even['antecedents'] + ' \u27f7 ' + rules_even['consequents']
rules_even= rules_even.sort_values('lift', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 rules_even = rules.iloc[::2, :].copy() # Keep only even rows.
#       2 rules_even.antecedents = rules_even.antecedents.apply(', '.join) # Get rid of frozensets.
#       3 rules_even.consequents = rules_even.consequents.apply(', '.join) # Get rid of frozensets.
#
# NameError: name 'rules' is not defined

# %%
sns.barplot(rules_even, y='cxns', x='lift').set_title('Coffee Shop Product Lift')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sns.barplot(rules_even, y='cxns', x='lift').set_title('Coffee Shop Product Lift')
#
# NameError: name 'rules_even' is not defined

# %% [markdown]
# Apparently, the sweet tooth wins out!
